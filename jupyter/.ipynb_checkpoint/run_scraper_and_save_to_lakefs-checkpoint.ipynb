# %%
# !pip install pandas selenium webdriver-manager pyarrow s3fs
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: selenium in /opt/conda/lib/python3.11/site-packages (4.32.0)
# Requirement already satisfied: webdriver-manager in /opt/conda/lib/python3.11/site-packages (4.0.2)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.11/site-packages (20.0.0)
# Requirement already satisfied: s3fs in /opt/conda/lib/python3.11/site-packages (2025.3.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /opt/conda/lib/python3.11/site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/conda/lib/python3.11/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/conda/lib/python3.11/site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions~=4.9 in /opt/conda/lib/python3.11/site-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8 in /opt/conda/lib/python3.11/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (from webdriver-manager) (1.1.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from webdriver-manager) (23.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.11/site-packages (from s3fs) (2.22.0)
# Requirement already satisfied: fsspec==2025.3.2.* in /opt/conda/lib/python3.11/site-packages (from s3fs) (2025.3.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from s3fs) (3.11.18)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Requirement already satisfied: botocore<1.37.4,>=1.37.2 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.37.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (6.4.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.20.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: sortedcontainers in /opt/conda/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /opt/conda/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/conda/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/conda/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->webdriver-manager) (3.3.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.16.0)

# %%
import time
import datetime
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import os
import re
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

class EGATRealTimeScraper:
    def __init__(self, url="https://www.sothailand.com/sysgen/egat/"):
        self.url = url
        self._initialize_driver()

    def _initialize_driver(self):
        chrome_options = Options()
        chrome_options.add_argument("--headless")
        chrome_options.add_argument("--no-sandbox")
        chrome_options.add_argument("--disable-dev-shm-usage")
        chrome_options.add_argument("--disable-gpu")
        chrome_options.add_argument("--window-size=1920,1080")
        chrome_options.set_capability('goog:loggingPrefs', {'browser': 'ALL'})
        
        service = Service(ChromeDriverManager().install())
        self.driver = webdriver.Chrome(service=service, options=chrome_options)

    def extract_data_from_console(self):
        logs = self.driver.get_log('browser')
        
        for log_entry in reversed(logs):
            message = log_entry.get('message', '')
            if 'updateMessageArea:' in message:
                match = re.search(r'updateMessageArea:\s*(\d+)\s*,\s*(\d{1,2}:\d{2})\s*,\s*([\d,]+\.?\d*)\s*,\s*(\d+\.?\d*)', message)
                if match:
                    display_date_id = match.group(1).strip()
                    display_time = match.group(2).strip()
                    current_value_mw = float(match.group(3).replace(',', '').strip())
                    temperature_c = float(match.group(4).strip())

                    return {
                        'scrape_timestamp_utc': datetime.datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S'),
                        'display_date_id': display_date_id,
                        'display_time': display_time,
                        'current_value_MW': current_value_mw,
                        'temperature_C': temperature_c
                    }
        return None

    def scrape_once(self):
        self.driver.get(self.url)
        time.sleep(10)
        return self.extract_data_from_console()

    def close(self):
        if self.driver:
            self.driver.quit()
            self.driver = None

def perform_scrape_and_update(scraper, lakefs_s3_path, storage_options):
    existing_df = pd.DataFrame()
    
    existing_df = pd.read_parquet(lakefs_s3_path, storage_options=storage_options)
    if 'scrape_timestamp_utc' in existing_df.columns:
        existing_df['scrape_timestamp_utc'] = pd.to_datetime(existing_df['scrape_timestamp_utc'])

    new_data_dict = scraper.scrape_once()

    if new_data_dict:
        new_df = pd.DataFrame([new_data_dict])
        new_df['scrape_timestamp_utc'] = pd.to_datetime(new_df['scrape_timestamp_utc'])

        combined_df = pd.concat([existing_df, new_df], ignore_index=True) if not existing_df.empty else new_df

        key_cols_for_dedup = ['display_date_id', 'display_time']
        combined_df.sort_values('scrape_timestamp_utc', ascending=False, inplace=True)
        deduplicated_df = combined_df.drop_duplicates(subset=key_cols_for_dedup, keep='first')

        if 'display_date_id' in deduplicated_df.columns and 'display_time' in deduplicated_df.columns:
            deduplicated_df['temp_datetime_sort'] = pd.to_datetime(
                deduplicated_df['display_date_id'] + ' ' + deduplicated_df['display_time'],
                format='%Y%m%d %H:%M'
            )
            deduplicated_df.sort_values(by=['temp_datetime_sort', 'scrape_timestamp_utc'], ascending=[True, True], inplace=True)
            deduplicated_df.drop(columns=['temp_datetime_sort'], inplace=True)
        elif 'scrape_timestamp_utc' in deduplicated_df.columns:
            deduplicated_df.sort_values('scrape_timestamp_utc', ascending=True, inplace=True)

        deduplicated_df.to_parquet(
            lakefs_s3_path,
            storage_options=storage_options,
            index=False,
            engine='pyarrow',
            compression='snappy'
        )

def run_scraper_periodically():
    ACCESS_KEY = os.getenv("LAKEFS_ACCESS_KEY_ID")
    SECRET_KEY = os.getenv("LAKEFS_SECRET_ACCESS_KEY")
    LAKEFS_ENDPOINT = os.getenv("LAKEFS_ENDPOINT_URL")
    REPO_NAME = os.getenv("REPO_NAME")
    BRANCH_NAME = os.getenv("BRANCH_NAME")
    TARGET_PARQUET_FILE_PATH = os.getenv("TARGET_PARQUET_FILE_PATH")
    INTERVAL_MINUTES = int(os.getenv("SCRAPE_INTERVAL_MINUTES", "5"))
    
    lakefs_s3_path = f"s3a://{REPO_NAME}/{BRANCH_NAME}/{TARGET_PARQUET_FILE_PATH}"

    storage_options = {
        "key": ACCESS_KEY,
        "secret": SECRET_KEY,
        "client_kwargs": {
            "endpoint_url": LAKEFS_ENDPOINT
        }
    }

    scraper = EGATRealTimeScraper()

    while True:
        perform_scrape_and_update(scraper, lakefs_s3_path, storage_options)
        time.sleep(INTERVAL_MINUTES * 60)

    scraper.close()

if __name__ == "__main__":
    run_scraper_periodically()
# Out:
# 2025-05-18 13:08:32,235 - INFO - 835430248.py:208 - Configured LakeFS Target Path: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:08:32,236 - INFO - 835430248.py:209 - Scraping interval set to 5 minutes.
# 2025-05-18 13:08:32,237 - INFO - 835430248.py:27 - Initializing WebDriver...
# 2025-05-18 13:08:32,237 - INFO - logger.py:11 - ====== WebDriver manager ======
# 2025-05-18 13:08:32,336 - INFO - logger.py:11 - Get LATEST chromedriver version for google-chrome
# 2025-05-18 13:08:32,482 - INFO - logger.py:11 - Get LATEST chromedriver version for google-chrome
# 2025-05-18 13:08:32,584 - INFO - logger.py:11 - There is no [linux64] chromedriver "136.0.7103.94" for browser google-chrome "136.0.7103" in cache
# 2025-05-18 13:08:32,585 - INFO - logger.py:11 - Get LATEST chromedriver version for google-chrome
# 2025-05-18 13:08:33,149 - INFO - logger.py:11 - WebDriver version 136.0.7103.94 selected
# 2025-05-18 13:08:33,155 - INFO - logger.py:11 - Modern chrome version https://storage.googleapis.com/chrome-for-testing-public/136.0.7103.94/linux64/chromedriver-linux64.zip
# 2025-05-18 13:08:33,157 - INFO - logger.py:11 - About to download new driver from https://storage.googleapis.com/chrome-for-testing-public/136.0.7103.94/linux64/chromedriver-linux64.zip
# 2025-05-18 13:08:33,338 - INFO - logger.py:11 - Driver downloading response is 200
# 2025-05-18 13:08:34,391 - INFO - logger.py:11 - Get LATEST chromedriver version for google-chrome
# 2025-05-18 13:08:34,768 - INFO - logger.py:11 - Driver has been saved in cache [/home/jovyan/.wdm/drivers/chromedriver/linux64/136.0.7103.94]
# 2025-05-18 13:08:35,280 - INFO - 835430248.py:40 - WebDriver initialized successfully.
# 2025-05-18 13:08:35,281 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:08:35,285 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:08:36,059 - WARNING - 835430248.py:123 - Parquet file not found at s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet (FileNotFoundError). This is expected if it's the first run. A new file will be created.
# 2025-05-18 13:08:36,060 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:08:36,459 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:08:46,467 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:08:46', 'display_date_id': '71220', 'display_time': '19:47', 'current_value_MW': 28720.2, 'temperature_C': 30.7}
# 2025-05-18 13:08:46,468 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:08:46', 'display_date_id': '71220', 'display_time': '19:47', 'current_value_MW': 28720.2, 'temperature_C': 30.7}
# 2025-05-18 13:08:46,489 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:08:46,507 - INFO - 835430248.py:150 - Rows after deduplication: 1
# 2025-05-18 13:08:46,532 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:08:46,534 - INFO - 835430248.py:177 - Saving 1 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:08:46,637 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:08:46,638 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:08:46,639 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:13:46,605 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:13:46,624 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:13:46,955 - INFO - 835430248.py:119 - Successfully read 1 rows from existing Parquet file.
# 2025-05-18 13:13:46,968 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:13:47,166 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:13:57,170 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:13:57', 'display_date_id': '72120', 'display_time': '20:02', 'current_value_MW': 28746.6, 'temperature_C': 30.6}
# 2025-05-18 13:13:57,172 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:13:57', 'display_date_id': '72120', 'display_time': '20:02', 'current_value_MW': 28746.6, 'temperature_C': 30.6}
# 2025-05-18 13:13:57,183 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:13:57,190 - INFO - 835430248.py:150 - Rows after deduplication: 2
# 2025-05-18 13:13:57,198 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:13:57,200 - INFO - 835430248.py:177 - Saving 2 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:13:57,226 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:13:57,226 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:13:57,227 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:18:57,189 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:18:57,210 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:18:57,419 - INFO - 835430248.py:119 - Successfully read 2 rows from existing Parquet file.
# 2025-05-18 13:18:57,426 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:18:57,619 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:19:07,634 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:19:07', 'display_date_id': '72780', 'display_time': '20:13', 'current_value_MW': 29079.6, 'temperature_C': 30.6}
# 2025-05-18 13:19:07,637 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:19:07', 'display_date_id': '72780', 'display_time': '20:13', 'current_value_MW': 29079.6, 'temperature_C': 30.6}
# 2025-05-18 13:19:07,659 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:19:07,676 - INFO - 835430248.py:150 - Rows after deduplication: 3
# 2025-05-18 13:19:07,698 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:19:07,701 - INFO - 835430248.py:177 - Saving 3 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:19:07,753 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:19:07,756 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:19:07,758 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:24:07,721 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:24:07,754 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:24:07,926 - INFO - 835430248.py:119 - Successfully read 3 rows from existing Parquet file.
# 2025-05-18 13:24:07,928 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:24:08,001 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:24:18,017 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:24:18', 'display_date_id': '73320', 'display_time': '20:22', 'current_value_MW': 29254.9, 'temperature_C': 30.5}
# 2025-05-18 13:24:18,020 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:24:18', 'display_date_id': '73320', 'display_time': '20:22', 'current_value_MW': 29254.9, 'temperature_C': 30.5}
# 2025-05-18 13:24:18,046 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:24:18,062 - INFO - 835430248.py:150 - Rows after deduplication: 4
# 2025-05-18 13:24:18,084 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:24:18,088 - INFO - 835430248.py:177 - Saving 4 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:24:18,143 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:24:18,146 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:24:18,150 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:29:18,114 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:29:18,122 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:29:18,286 - INFO - 835430248.py:119 - Successfully read 4 rows from existing Parquet file.
# 2025-05-18 13:29:18,295 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:29:18,451 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:29:28,458 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:29:28', 'display_date_id': '73620', 'display_time': '20:27', 'current_value_MW': 29095.5, 'temperature_C': 30.5}
# 2025-05-18 13:29:28,461 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:29:28', 'display_date_id': '73620', 'display_time': '20:27', 'current_value_MW': 29095.5, 'temperature_C': 30.5}
# 2025-05-18 13:29:28,472 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:29:28,479 - INFO - 835430248.py:150 - Rows after deduplication: 5
# 2025-05-18 13:29:28,497 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:29:28,500 - INFO - 835430248.py:177 - Saving 5 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:29:28,547 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:29:28,550 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:29:28,553 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:34:28,516 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:34:28,538 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:34:28,750 - INFO - 835430248.py:119 - Successfully read 5 rows from existing Parquet file.
# 2025-05-18 13:34:28,756 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:34:28,892 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:34:38,909 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:34:38', 'display_date_id': '73920', 'display_time': '20:32', 'current_value_MW': 29353.6, 'temperature_C': 30.5}
# 2025-05-18 13:34:38,913 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:34:38', 'display_date_id': '73920', 'display_time': '20:32', 'current_value_MW': 29353.6, 'temperature_C': 30.5}
# 2025-05-18 13:34:38,934 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:34:38,949 - INFO - 835430248.py:150 - Rows after deduplication: 6
# 2025-05-18 13:34:38,970 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:34:38,974 - INFO - 835430248.py:177 - Saving 6 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:34:39,043 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:34:39,044 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:34:39,045 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:39:39,011 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:39:39,018 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:39:39,131 - INFO - 835430248.py:119 - Successfully read 6 rows from existing Parquet file.
# 2025-05-18 13:39:39,133 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:39:39,304 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:39:49,319 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:39:49', 'display_date_id': '74280', 'display_time': '20:38', 'current_value_MW': 29343.4, 'temperature_C': 30.4}
# 2025-05-18 13:39:49,322 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:39:49', 'display_date_id': '74280', 'display_time': '20:38', 'current_value_MW': 29343.4, 'temperature_C': 30.4}
# 2025-05-18 13:39:49,336 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:39:49,344 - INFO - 835430248.py:150 - Rows after deduplication: 7
# 2025-05-18 13:39:49,360 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:39:49,364 - INFO - 835430248.py:177 - Saving 7 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:39:49,409 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:39:49,412 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:39:49,415 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:44:49,384 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:44:49,398 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:44:49,576 - INFO - 835430248.py:119 - Successfully read 7 rows from existing Parquet file.
# 2025-05-18 13:44:49,581 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:44:49,736 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:44:59,746 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:44:59', 'display_date_id': '74580', 'display_time': '20:43', 'current_value_MW': 29259.3, 'temperature_C': 30.4}
# 2025-05-18 13:44:59,749 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:44:59', 'display_date_id': '74580', 'display_time': '20:43', 'current_value_MW': 29259.3, 'temperature_C': 30.4}
# 2025-05-18 13:44:59,768 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:44:59,781 - INFO - 835430248.py:150 - Rows after deduplication: 8
# 2025-05-18 13:44:59,806 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:44:59,809 - INFO - 835430248.py:177 - Saving 8 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:44:59,860 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:44:59,863 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:44:59,867 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:49:59,831 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:49:59,837 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:49:59,971 - INFO - 835430248.py:119 - Successfully read 8 rows from existing Parquet file.
# 2025-05-18 13:49:59,974 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:50:00,077 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:50:10,091 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:50:10', 'display_date_id': '74880', 'display_time': '20:48', 'current_value_MW': 29224.5, 'temperature_C': 30.4}
# 2025-05-18 13:50:10,094 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:50:10', 'display_date_id': '74880', 'display_time': '20:48', 'current_value_MW': 29224.5, 'temperature_C': 30.4}
# 2025-05-18 13:50:10,108 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:50:10,121 - INFO - 835430248.py:150 - Rows after deduplication: 9
# 2025-05-18 13:50:10,143 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:50:10,145 - INFO - 835430248.py:177 - Saving 9 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:50:10,196 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:50:10,199 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:50:10,204 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 13:55:10,168 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 13:55:10,173 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:55:10,338 - INFO - 835430248.py:119 - Successfully read 9 rows from existing Parquet file.
# 2025-05-18 13:55:10,343 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 13:55:10,553 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 13:55:20,569 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 13:55:20', 'display_date_id': '75180', 'display_time': '20:53', 'current_value_MW': 29136.2, 'temperature_C': 30.4}
# 2025-05-18 13:55:20,571 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 13:55:20', 'display_date_id': '75180', 'display_time': '20:53', 'current_value_MW': 29136.2, 'temperature_C': 30.4}
# 2025-05-18 13:55:20,579 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 13:55:20,584 - INFO - 835430248.py:150 - Rows after deduplication: 10
# 2025-05-18 13:55:20,590 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 13:55:20,591 - INFO - 835430248.py:177 - Saving 10 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 13:55:20,616 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 13:55:20,617 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 13:55:20,618 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:00:20,581 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:00:20,586 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:00:20,736 - INFO - 835430248.py:119 - Successfully read 10 rows from existing Parquet file.
# 2025-05-18 14:00:20,738 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:00:20,817 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:00:30,834 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:00:30', 'display_date_id': '75480', 'display_time': '20:58', 'current_value_MW': 28957.7, 'temperature_C': 30.3}
# 2025-05-18 14:00:30,835 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:00:30', 'display_date_id': '75480', 'display_time': '20:58', 'current_value_MW': 28957.7, 'temperature_C': 30.3}
# 2025-05-18 14:00:30,838 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:00:30,845 - INFO - 835430248.py:150 - Rows after deduplication: 11
# 2025-05-18 14:00:30,849 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:00:30,850 - INFO - 835430248.py:177 - Saving 11 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:00:30,871 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:00:30,872 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:00:30,873 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:05:30,833 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:05:30,839 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:05:31,024 - INFO - 835430248.py:119 - Successfully read 11 rows from existing Parquet file.
# 2025-05-18 14:05:31,027 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:05:31,108 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:05:41,115 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:05:41', 'display_date_id': '75780', 'display_time': '21:03', 'current_value_MW': 28906.5, 'temperature_C': 30.3}
# 2025-05-18 14:05:41,116 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:05:41', 'display_date_id': '75780', 'display_time': '21:03', 'current_value_MW': 28906.5, 'temperature_C': 30.3}
# 2025-05-18 14:05:41,121 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:05:41,127 - INFO - 835430248.py:150 - Rows after deduplication: 12
# 2025-05-18 14:05:41,134 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:05:41,136 - INFO - 835430248.py:177 - Saving 12 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:05:41,163 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:05:41,165 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:05:41,167 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:10:41,099 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:10:41,108 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:10:41,293 - INFO - 835430248.py:119 - Successfully read 12 rows from existing Parquet file.
# 2025-05-18 14:10:41,295 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:10:41,388 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:10:51,393 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:10:51', 'display_date_id': '76140', 'display_time': '21:09', 'current_value_MW': 28795.7, 'temperature_C': 30.3}
# 2025-05-18 14:10:51,394 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:10:51', 'display_date_id': '76140', 'display_time': '21:09', 'current_value_MW': 28795.7, 'temperature_C': 30.3}
# 2025-05-18 14:10:51,398 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:10:51,401 - INFO - 835430248.py:150 - Rows after deduplication: 13
# 2025-05-18 14:10:51,405 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:10:51,406 - INFO - 835430248.py:177 - Saving 13 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:10:51,431 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:10:51,435 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:10:51,438 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:15:51,377 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:15:51,383 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:15:51,531 - INFO - 835430248.py:119 - Successfully read 13 rows from existing Parquet file.
# 2025-05-18 14:15:51,533 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:15:51,630 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:16:01,629 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:16:01', 'display_date_id': '76500', 'display_time': '21:15', 'current_value_MW': 28864.5, 'temperature_C': 30.2}
# 2025-05-18 14:16:01,630 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:16:01', 'display_date_id': '76500', 'display_time': '21:15', 'current_value_MW': 28864.5, 'temperature_C': 30.2}
# 2025-05-18 14:16:01,634 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:16:01,637 - INFO - 835430248.py:150 - Rows after deduplication: 14
# 2025-05-18 14:16:01,645 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:16:01,646 - INFO - 835430248.py:177 - Saving 14 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:16:01,674 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:16:01,675 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:16:01,676 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:21:01,616 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:21:01,621 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:21:01,773 - INFO - 835430248.py:119 - Successfully read 14 rows from existing Parquet file.
# 2025-05-18 14:21:01,775 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:21:01,866 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:21:11,871 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:21:11', 'display_date_id': '76740', 'display_time': '21:19', 'current_value_MW': 28851.4, 'temperature_C': 30.2}
# 2025-05-18 14:21:11,872 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:21:11', 'display_date_id': '76740', 'display_time': '21:19', 'current_value_MW': 28851.4, 'temperature_C': 30.2}
# 2025-05-18 14:21:11,875 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:21:11,878 - INFO - 835430248.py:150 - Rows after deduplication: 15
# 2025-05-18 14:21:11,884 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:21:11,885 - INFO - 835430248.py:177 - Saving 15 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:21:11,910 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:21:11,911 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:21:11,911 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:26:11,855 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:26:11,863 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:26:12,040 - INFO - 835430248.py:119 - Successfully read 15 rows from existing Parquet file.
# 2025-05-18 14:26:12,042 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:26:12,118 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:26:22,124 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:26:22', 'display_date_id': '77100', 'display_time': '21:25', 'current_value_MW': 28788.4, 'temperature_C': 30.2}
# 2025-05-18 14:26:22,125 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:26:22', 'display_date_id': '77100', 'display_time': '21:25', 'current_value_MW': 28788.4, 'temperature_C': 30.2}
# 2025-05-18 14:26:22,130 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:26:22,135 - INFO - 835430248.py:150 - Rows after deduplication: 16
# 2025-05-18 14:26:22,140 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:26:22,141 - INFO - 835430248.py:177 - Saving 16 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:26:22,166 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:26:22,167 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:26:22,169 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:31:22,115 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:31:22,117 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:31:22,182 - INFO - 835430248.py:119 - Successfully read 16 rows from existing Parquet file.
# 2025-05-18 14:31:22,183 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:31:22,247 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:31:32,255 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:31:32', 'display_date_id': '77340', 'display_time': '21:29', 'current_value_MW': 28736.4, 'temperature_C': 30.2}
# 2025-05-18 14:31:32,258 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:31:32', 'display_date_id': '77340', 'display_time': '21:29', 'current_value_MW': 28736.4, 'temperature_C': 30.2}
# 2025-05-18 14:31:32,276 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:31:32,289 - INFO - 835430248.py:150 - Rows after deduplication: 17
# 2025-05-18 14:31:32,320 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:31:32,325 - INFO - 835430248.py:177 - Saving 17 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:31:32,380 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:31:32,381 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:31:32,382 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:36:32,334 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:36:32,339 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:36:32,502 - INFO - 835430248.py:119 - Successfully read 17 rows from existing Parquet file.
# 2025-05-18 14:36:32,514 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:36:32,633 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:36:42,637 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:36:42', 'display_date_id': '77700', 'display_time': '21:35', 'current_value_MW': 28703.0, 'temperature_C': 30.1}
# 2025-05-18 14:36:42,638 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:36:42', 'display_date_id': '77700', 'display_time': '21:35', 'current_value_MW': 28703.0, 'temperature_C': 30.1}
# 2025-05-18 14:36:42,642 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:36:42,644 - INFO - 835430248.py:150 - Rows after deduplication: 18
# 2025-05-18 14:36:42,649 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:36:42,650 - INFO - 835430248.py:177 - Saving 18 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:36:42,673 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:36:42,675 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:36:42,676 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:41:42,631 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:41:42,657 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:41:42,807 - INFO - 835430248.py:119 - Successfully read 18 rows from existing Parquet file.
# 2025-05-18 14:41:42,812 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:41:42,913 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:41:52,920 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:41:52', 'display_date_id': '78060', 'display_time': '21:41', 'current_value_MW': 28573.0, 'temperature_C': 30.1}
# 2025-05-18 14:41:52,921 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:41:52', 'display_date_id': '78060', 'display_time': '21:41', 'current_value_MW': 28573.0, 'temperature_C': 30.1}
# 2025-05-18 14:41:52,927 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:41:52,936 - INFO - 835430248.py:150 - Rows after deduplication: 19
# 2025-05-18 14:41:52,944 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:41:52,945 - INFO - 835430248.py:177 - Saving 19 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:41:52,980 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:41:52,982 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:41:52,983 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:46:52,938 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:46:52,944 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:46:53,027 - INFO - 835430248.py:119 - Successfully read 19 rows from existing Parquet file.
# 2025-05-18 14:46:53,028 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:46:53,109 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:47:03,111 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:47:03', 'display_date_id': '78300', 'display_time': '21:45', 'current_value_MW': 28320.4, 'temperature_C': 30.1}
# 2025-05-18 14:47:03,112 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:47:03', 'display_date_id': '78300', 'display_time': '21:45', 'current_value_MW': 28320.4, 'temperature_C': 30.1}
# 2025-05-18 14:47:03,117 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:47:03,121 - INFO - 835430248.py:150 - Rows after deduplication: 20
# 2025-05-18 14:47:03,127 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:47:03,128 - INFO - 835430248.py:177 - Saving 20 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:47:03,154 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:47:03,155 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:47:03,156 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:52:03,111 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:52:03,118 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:52:03,210 - INFO - 835430248.py:119 - Successfully read 20 rows from existing Parquet file.
# 2025-05-18 14:52:03,214 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:52:03,402 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:52:13,408 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:52:13', 'display_date_id': '78660', 'display_time': '21:51', 'current_value_MW': 28291.4, 'temperature_C': 30.1}
# 2025-05-18 14:52:13,409 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:52:13', 'display_date_id': '78660', 'display_time': '21:51', 'current_value_MW': 28291.4, 'temperature_C': 30.1}
# 2025-05-18 14:52:13,418 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:52:13,424 - INFO - 835430248.py:150 - Rows after deduplication: 21
# 2025-05-18 14:52:13,430 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:52:13,431 - INFO - 835430248.py:177 - Saving 21 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:52:13,455 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:52:13,455 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:52:13,456 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 14:57:13,415 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 14:57:13,423 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:57:13,519 - INFO - 835430248.py:119 - Successfully read 21 rows from existing Parquet file.
# 2025-05-18 14:57:13,521 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 14:57:13,617 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 14:57:23,625 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 14:57:23', 'display_date_id': '78900', 'display_time': '21:55', 'current_value_MW': 28335.2, 'temperature_C': 30.1}
# 2025-05-18 14:57:23,628 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 14:57:23', 'display_date_id': '78900', 'display_time': '21:55', 'current_value_MW': 28335.2, 'temperature_C': 30.1}
# 2025-05-18 14:57:23,647 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 14:57:23,662 - INFO - 835430248.py:150 - Rows after deduplication: 22
# 2025-05-18 14:57:23,687 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 14:57:23,690 - INFO - 835430248.py:177 - Saving 22 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 14:57:23,743 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 14:57:23,746 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 14:57:23,750 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 15:02:23,712 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 15:02:23,720 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 15:02:23,794 - INFO - 835430248.py:119 - Successfully read 22 rows from existing Parquet file.
# 2025-05-18 15:02:23,796 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 15:02:23,890 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 15:02:33,902 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 15:02:33', 'display_date_id': '79260', 'display_time': '22:01', 'current_value_MW': 28115.6, 'temperature_C': 30.1}
# 2025-05-18 15:02:33,904 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 15:02:33', 'display_date_id': '79260', 'display_time': '22:01', 'current_value_MW': 28115.6, 'temperature_C': 30.1}
# 2025-05-18 15:02:33,918 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 15:02:33,928 - INFO - 835430248.py:150 - Rows after deduplication: 23
# 2025-05-18 15:02:33,948 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 15:02:33,950 - INFO - 835430248.py:177 - Saving 23 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 15:02:33,995 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 15:02:33,997 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 15:02:34,000 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 15:07:33,958 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 15:07:33,963 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 15:07:34,042 - INFO - 835430248.py:119 - Successfully read 23 rows from existing Parquet file.
# 2025-05-18 15:07:34,044 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 15:07:34,121 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 15:07:44,133 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 15:07:44', 'display_date_id': '79500', 'display_time': '22:05', 'current_value_MW': 28039.9, 'temperature_C': 30.1}
# 2025-05-18 15:07:44,136 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 15:07:44', 'display_date_id': '79500', 'display_time': '22:05', 'current_value_MW': 28039.9, 'temperature_C': 30.1}
# 2025-05-18 15:07:44,154 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 15:07:44,168 - INFO - 835430248.py:150 - Rows after deduplication: 24
# 2025-05-18 15:07:44,188 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 15:07:44,193 - INFO - 835430248.py:177 - Saving 24 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 15:07:44,311 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 15:07:44,312 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 15:07:44,313 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 15:12:44,271 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 15:12:44,275 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 15:12:44,371 - INFO - 835430248.py:119 - Successfully read 24 rows from existing Parquet file.
# 2025-05-18 15:12:44,373 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 15:12:44,480 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 15:12:54,491 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 15:12:54', 'display_date_id': '79680', 'display_time': '22:08', 'current_value_MW': 27960.5, 'temperature_C': 30.1}
# 2025-05-18 15:12:54,497 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 15:12:54', 'display_date_id': '79680', 'display_time': '22:08', 'current_value_MW': 27960.5, 'temperature_C': 30.1}
# 2025-05-18 15:12:54,512 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 15:12:54,522 - INFO - 835430248.py:150 - Rows after deduplication: 25
# 2025-05-18 15:12:54,546 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 15:12:54,549 - INFO - 835430248.py:177 - Saving 25 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 15:12:54,604 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 15:12:54,606 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 15:12:54,607 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
# 2025-05-18 16:09:21,951 - INFO - 835430248.py:113 - --- Starting new scrape and update cycle ---
# 2025-05-18 16:09:21,955 - INFO - 835430248.py:117 - Attempting to read existing Parquet from: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 16:09:22,033 - INFO - 835430248.py:119 - Successfully read 25 rows from existing Parquet file.
# 2025-05-18 16:09:22,035 - INFO - 835430248.py:89 - Navigating to URL: https://www.sothailand.com/sysgen/egat/
# 2025-05-18 16:09:23,222 - INFO - 835430248.py:91 - Waiting for page load and data (10 seconds)...
# 2025-05-18 16:09:33,238 - INFO - 835430248.py:74 - Data extracted: {'scrape_timestamp_utc': '2025-05-18 16:09:33', 'display_date_id': '83160', 'display_time': '23:06', 'current_value_MW': 26690.9, 'temperature_C': 29.8}
# 2025-05-18 16:09:33,240 - INFO - 835430248.py:139 - Scraped new data: {'scrape_timestamp_utc': '2025-05-18 16:09:33', 'display_date_id': '83160', 'display_time': '23:06', 'current_value_MW': 26690.9, 'temperature_C': 29.8}
# 2025-05-18 16:09:33,248 - INFO - 835430248.py:147 - Deduplicating data...
# 2025-05-18 16:09:33,252 - INFO - 835430248.py:150 - Rows after deduplication: 26
# 2025-05-18 16:09:33,260 - INFO - 835430248.py:169 - Sorted final DataFrame.
# 2025-05-18 16:09:33,262 - INFO - 835430248.py:177 - Saving 26 rows to LakeFS: s3a://dataset/main/egat_datascraping/egat_realtime_power_history.parquet
# 2025-05-18 16:09:33,288 - INFO - 835430248.py:183 - Successfully saved data to LakeFS.
# 2025-05-18 16:09:33,289 - INFO - 835430248.py:188 - --- Scrape and update cycle finished ---
# 2025-05-18 16:09:33,290 - INFO - 835430248.py:222 - Waiting for 5 minutes (300 seconds) before next cycle...
